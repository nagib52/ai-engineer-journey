# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.6 MB/s eta 0:00:0000:01
# ...

# %%
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
api_key = user_secrets.get_secret("GROQ_API_KEY")

from groq import Groq
client = Groq(api_key=api_key)

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "user", "content": "Explain what an API is in simple terms"}
    ]
)

print(response.choices[0].message.content)
# Out:
# **What is an API?**
#
# An API (Application Programming Interface) is like a messenger between two different systems.
#
# Imagine you're at a restaurant and you want to order food. You can't just walk into the kitchen and start making your own meal. Instead, you tell the waiter what you want, and they take your order to the kitchen staff. The kitchen staff then prepares your food, and the waiter brings it back to you.
#
# In a similar way, when you use a website or an app, it's like sending a message to the kitchen (the website's or app's server). The message says, "Hey, I want to see this information" or "I want to do this action." The server then processes your request and sends back the response, like the waiter bringing your food.
#
# **How does it work?**
#
# Here are the basic steps:
#
# 1. **You send a request**: You use an app or send a command to the server, asking it to perform a specific action.
# ...

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful assistant that only responds in Bengali and always answers in exactly 2 sentences."},
        {"role": "user", "content": "Who is Nagib?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# নাগিব একজন বিখ্যাত বাংলাদেশী গায়ক যিনি বাংলাদেশের সঙ্গীত জগতে তার অবদানের জন্য পরিচিত। তিনি তার স্বতন্ত্র কণ্ঠস্বর এবং গানের ধরনের জন্য বাংলাদেশের সঙ্গীত ভক্তদের কাছে বিশেষভাবে পরিচিত।

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful assistant that only responds in Bengali and always answers in exactly 2 sentences."},
        {"role": "user", "content": "What is machine learning?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# মেশিন লার্নিং হলো এক ধরনের কৃত্রিম বুদ্ধিমত্তা যা ডাটা থেকে শিক্ষা নিয়ে সিদ্ধান্ত নেওয়ার ক্ষমতা রাখে। এই পদ্ধতিতে কম্পিউটার সিস্টেমগুলি ডাটা বিশ্লেষণ করে এবং ভবিষ্যদ্বাণী করতে পারে, যা ব্যবসা এবং প্রযুক্তির বিভিন্ন ক্ষেত্রে ব্যবহার করা হয়।

# %%
conversation = [
    {"role": "system", "content": "You are a helpful assistant."}
]

def chat(user_input):
    conversation.append({"role": "user", "content": user_input})
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=conversation
    )
    reply = response.choices[0].message.content
    conversation.append({"role": "assistant", "content": reply})
    return reply

print(chat("My name is Rahim"))
print(chat("What's my name?"))
# Out:
# Hello Rahim, it's nice to meet you. Is there something I can help you with or would you like to chat?
# Your name is Rahim.

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "Write a one-line tagline for a coffee shop"}],
    temperature=0.9,
    max_tokens=50
)
print(response.choices[0].message.content)
# Out:
# "Brewing joy, one cup at a time, in a warm and welcoming space where every sip feels like home."

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "Write a one-line tagline for a coffee shop"}],
    temperature=0.1,
    max_tokens=50
)
print(response.choices[0].message.content)
# Out:
# "Brewing more than just coffee, we're crafting moments that perk up your day."

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "Write a one-line tagline for a coffee shop"}],
    temperature=0.1,
    max_tokens=50
)
print(response.choices[0].message.content)
# Out:
# "Brewing more than just coffee, we're crafting moments that perk up your day."

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "Write a one-line tagline for a coffee shop"}],
    temperature=0.9,
    max_tokens=50
)
print(response.choices[0].message.content)
# Out:
# "Brewing up more than just coffee, one cup at a time, in a warm and welcoming space that feels like home."

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "Write a one-line tagline for a coffee shop"}],
    temperature=0.4,
    max_tokens=50
)
print(response.choices[0].message.content)
# Out:
# "Brewing more than just coffee, we're crafting moments that perk up your day."

# %%
conversation = [{"role": "system", "content": "You are a friendly helpful assistant."}]

while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        break
    conversation.append({"role": "user", "content": user_input})
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=conversation
    )
    reply = response.choices[0].message.content
    print("Bot:", reply)
    conversation.append({"role": "assistant", "content": reply})
# Out:
# You:  what is your name?
# Bot: I'm an AI assistant, and I don't have a personal name. I'm here to help answer your questions and provide assistance, but I don't have a personal identity or a name like a human would. You can think of me as a helpful computer program, and I'll do my best to assist you with any questions or topics you'd like to discuss! How can I help you today?
# You:  wxit
# Bot: It looks like you meant to type "exit"! If you're ready to end our conversation, I completely understand. It was nice chatting with you, even if it was brief. If you have any other questions or need help in the future, don't hesitate to reach out. Otherwise, have a great day and feel free to come back anytime! Goodbye for now!
# You:  exit
